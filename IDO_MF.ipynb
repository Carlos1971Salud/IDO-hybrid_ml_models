# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
nep = pd.read_csv('/content/archive (17).csv')
nep['time'] = pd.to_datetime(nep['time'])
nep_grouped = nep.groupby(pd.Grouper(key='time',freq='M'))
nep = nep_grouped.mean()

# %%
nep
# Out:
#                   tem        hum       pre         rad
# time
# 2009-01-31  12.351613  76.032258  0.024731  126.990591
# 2009-02-28  13.299107  69.392857  0.010119  168.258929
# 2009-03-31  15.252957  60.388441  0.021505  188.826613
# 2009-04-30  19.696111  56.876389  0.006944  216.363889
# 2009-05-31  20.467070  69.569892  0.208065  161.588710
# ...               ...        ...       ...         ...
# 2023-02-28  13.411458  73.169643  0.033929  136.099702
# 2023-03-31  14.893952  67.083333  0.107661  162.352151
# 2023-04-30  18.105556  59.570833  0.063472  190.684722
# 2023-05-31  19.893011  68.274194  0.122177  185.288978
# 2023-06-30  22.786944  76.234722  0.567917  144.600000
#
# [174 rows x 4 columns]

# %%
ind = pd.read_csv('/content/archive (4).csv')
ind['time'] = pd.to_datetime(ind['time'])
ind_grouped = ind.groupby(pd.Grouper(key='time',freq='M'))
ind = ind_grouped.mean()

# %%
ind
# Out:
#                   tem        hum       pre         rad
# time
# 2009-01-31  20.906586  52.256720  0.002554  150.690860
# 2009-02-28  24.166518  31.305060  0.000000  198.681548
# 2009-03-31  26.951882  25.439516  0.008065  210.817204
# 2009-04-30  30.905000  19.020833  0.005556  242.305556
# 2009-05-31  33.304032  25.467742  0.008468  224.685484
# ...               ...        ...       ...         ...
# 2023-02-28  21.809821  35.090774  0.000000  202.196429
# 2023-03-31  24.249597  42.634409  0.024866  178.692204
# 2023-04-30  27.210833  40.913889  0.054444  193.245833
# 2023-05-31  29.207930  41.880376  0.031317  212.884409
# 2023-06-30  29.462500  52.318056  0.260000  153.709722
#
# [174 rows x 4 columns]

# %%
ban = pd.read_csv('/content/archive (8).csv')
ban['time'] = pd.to_datetime(ban['time'])
ban_grouped = ban.groupby(pd.Grouper(key='time',freq='M'))
ban = ban_grouped.mean()

# %%
afg = pd.read_csv('/content/archive (16).csv')
afg['time'] = pd.to_datetime(afg['time'])
afg_grouped = afg.groupby(pd.Grouper(key='time',freq='M'))
afg = afg_grouped.mean()

# %%
pak = pd.read_csv('/content/archive (15).csv')
pak['time'] = pd.to_datetime(pak['time'])
pak_grouped = pak.groupby(pd.Grouper(key='time',freq='M'))
pak = pak_grouped.mean()

# %%
bhu = pd.read_csv('/content/archive (14).csv')
bhu['time'] = pd.to_datetime(bhu['time'])
bhu_grouped = bhu.groupby(pd.Grouper(key='time',freq='M'))
bhu = bhu_grouped.mean()

# %%
mal = pd.read_csv('/content/archive (13).csv')
mal['time'] = pd.to_datetime(mal['time'])
mal_grouped = mal.groupby(pd.Grouper(key='time',freq='M'))
mal = mal_grouped.mean()

# %%
sri = pd.read_csv('/content/archive (5).csv')
sri['time'] = pd.to_datetime(sri['time'])
sri_grouped = sri.groupby(pd.Grouper(key='time',freq='M'))
sri = sri_grouped.mean()

# %%
sri['tem'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
sri.reset_index(inplace=True)

# %%
sri
# Out:
#           time        tem        hum       pre         rad
# 0   2009-01-31  22.340323  82.348118  0.213441  119.643817
# 1   2009-02-28  23.286607  74.830357  0.020238  192.373512
# 2   2009-03-31  25.006452  78.361559  0.245699  201.092742
# 3   2009-04-30  26.034167  80.290278  0.119583  176.431944
# 4   2009-05-31  26.515860  77.055108  0.065860  164.233871
# ..         ...        ...        ...       ...         ...
# 169 2023-02-28  23.265625  83.404762  0.122173  129.544643
# 170 2023-03-31  24.769758  83.262097  0.179167  156.552419
# 171 2023-04-30  26.150139  80.036111  0.221528  194.904167
# 172 2023-05-31  26.264651  80.944892  0.150000  162.215054
# 173 2023-06-30  26.654583  75.108333  0.056250  169.425000
#
# [174 rows x 5 columns]

# %%
sri['time'] = sri['time'] - pd.to_timedelta(sri['time'].dt.day - 1, unit='D')

# %%
sri
# Out:
#           time        tem        hum       pre         rad
# 0   2009-01-01  22.340323  82.348118  0.213441  119.643817
# 1   2009-02-01  23.286607  74.830357  0.020238  192.373512
# 2   2009-03-01  25.006452  78.361559  0.245699  201.092742
# 3   2009-04-01  26.034167  80.290278  0.119583  176.431944
# 4   2009-05-01  26.515860  77.055108  0.065860  164.233871
# ..         ...        ...        ...       ...         ...
# 169 2023-02-01  23.265625  83.404762  0.122173  129.544643
# 170 2023-03-01  24.769758  83.262097  0.179167  156.552419
# 171 2023-04-01  26.150139  80.036111  0.221528  194.904167
# 172 2023-05-01  26.264651  80.944892  0.150000  162.215054
# 173 2023-06-01  26.654583  75.108333  0.056250  169.425000
#
# [174 rows x 5 columns]

# %%
sri.to_csv('Sri.csv')

# %%
ban.reset_index(inplace=True)
ban['time'] = ban['time'] - pd.to_timedelta(ban['time'].dt.day - 1, unit='D')

# %%
ban[ban['time']>='2010-01-01']
# Out:
#           time        tem        hum       pre         rad
# 12  2010-01-01  18.835349  70.544355  0.001747  151.583333
# 13  2010-02-01  22.713542  60.025298  0.017560  165.205357
# 14  2010-03-01  28.151613  61.135753  0.067876  198.939516
# 15  2010-04-01  30.159167  71.508333  0.146944  169.112500
# 16  2010-05-01  28.722715  82.881720  0.387231  107.633065
# ..         ...        ...        ...       ...         ...
# 169 2023-02-01  22.188393  64.552083  0.003571  160.897321
# 170 2023-03-01  25.029704  69.849462  0.167204  159.264785
# 171 2023-04-01  28.530972  67.027778  0.055972  199.670833
# 172 2023-05-01  28.878763  74.444892  0.343011  158.107527
# 173 2023-06-01  29.680139  82.051389  0.316389  109.915278
#
# [162 rows x 5 columns]

# %%
ban[ban['time']>='2010-01-01'].to_csv('Ban.csv')

# %%
ind
# Out:
#                   tem        hum       pre         rad
# time
# 2009-01-31  20.906586  52.256720  0.002554  150.690860
# 2009-02-28  24.166518  31.305060  0.000000  198.681548
# 2009-03-31  26.951882  25.439516  0.008065  210.817204
# 2009-04-30  30.905000  19.020833  0.005556  242.305556
# 2009-05-31  33.304032  25.467742  0.008468  224.685484
# ...               ...        ...       ...         ...
# 2023-02-28  21.809821  35.090774  0.000000  202.196429
# 2023-03-31  24.249597  42.634409  0.024866  178.692204
# 2023-04-30  27.210833  40.913889  0.054444  193.245833
# 2023-05-31  29.207930  41.880376  0.031317  212.884409
# 2023-06-30  29.462500  52.318056  0.260000  153.709722
#
# [174 rows x 4 columns]

# %%
ind.reset_index(inplace=True)
ind['time'] = ind['time'] - pd.to_timedelta(ind['time'].dt.day - 1, unit='D')
ind.to_csv('Ind2.csv')

# %%
nep.reset_index(inplace=True)
nep['time'] = nep['time'] - pd.to_timedelta(nep['time'].dt.day - 1, unit='D')
nep[nep['time']>='2011-06-01'].to_csv('Nep2.csv')

# %%
nep.reset_index(inplace=True)
nep['time'] = nep['time'] - pd.to_timedelta(nep['time'].dt.day - 1, unit='D')
nep[nep['time']>='2011-06-01'].to_csv('Nep2.csv')

# %%
afg.reset_index(inplace=True)
afg['time'] = afg['time'] - pd.to_timedelta(afg['time'].dt.day - 1, unit='D')
afg[afg['time']>='2009-10-01'].to_csv('Afg2.csv')

# %%
bhu.reset_index(inplace=True)
bhu['time'] = bhu['time'] - pd.to_timedelta(bhu['time'].dt.day - 1, unit='D')
bhu[bhu['time']>='2011-04-01'].to_csv('Bhu2.csv')

# %%
pak.reset_index(inplace=True)
pak['time'] = pak['time'] - pd.to_timedelta(pak['time'].dt.day - 1, unit='D')
pak.to_csv('Pak2.csv')

# %%
mal.reset_index(inplace=True)
mal['time'] = mal['time'] - pd.to_timedelta(mal['time'].dt.day - 1, unit='D')
mal[mal['time']>='2015-02-01'].to_csv('Mal3.csv')
