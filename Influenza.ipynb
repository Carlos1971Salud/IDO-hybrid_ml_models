# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/influenza (2).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30329 entries, 0 to 30328
# Columns: 128 entries, Country to ari_cases_per_thousand_outpatients
# dtypes: float64(126), object(2)
# memory usage: 29.6+ MB

# %%
df.head()
# Out:
#        Country       Month  Reported cases of acute respiratory infections  \
# 0  Afghanistan  2009-09-01                                             NaN
# 1  Afghanistan  2009-10-01                                             NaN
# 2  Afghanistan  2009-11-01                                             NaN
# 3  Afghanistan  2009-12-01                                             NaN
# 4  Afghanistan  2010-01-01                                             NaN
#
#    Reported cases of severe acute respiratory infections  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Reported cases of influenza-like illnesses  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
df.columns[:50]
# Out:
# Index(['Country', 'Month', 'Reported cases of acute respiratory infections',
#        'Reported cases of severe acute respiratory infections',
#        'Reported cases of influenza-like illnesses',
#        'Reported deaths caused by severe acute respiratory infections',
#        'Reported cases of influenza-like illness per thousand outpatients',
#        'Reported cases of severe acute respiratory illness per thousand outpatients',
#        'A H1N12009 - Sentinel surveillance',
#        'A H1N12009 - Non-sentinel surveillance',
#        'A H1N12009 - Undefined surveillance',
#        'A H1N12009 - All types of surveillance',
#        'A H1 - Sentinel surveillance', 'A H1 - Non-sentinel surveillance',
#        'A H1 - Undefined surveillance', 'A H1 - All types of surveillance',
#        'A H3 - Sentinel surveillance', 'A H3 - Non-sentinel surveillance',
#        'A H3 - Undefined surveillance', 'A H3 - All types of surveillance',
# ...

# %%
df[(df['Country']=='Bangladesh') & (df['Month']=='2023-06-01')]
# Out:
#          Country       Month  Reported cases of acute respiratory infections  \
# 2519  Bangladesh  2023-06-01                                             NaN
#
#       Reported cases of severe acute respiratory infections  \
# 2519                                              748.0
#
#       Reported cases of influenza-like illnesses  \
# 2519                                       558.0
#
#       Reported deaths caused by severe acute respiratory infections  \
# 2519                                                NaN
#
#       Reported cases of influenza-like illness per thousand outpatients  \
# 2519                                           2.888882
#
#       Reported cases of severe acute respiratory illness per thousand outpatients  \
# 2519                                           0.860686
#
#       A H1N12009 - Sentinel surveillance  \
# 2519                                 3.0
#
#       A H1N12009 - Non-sentinel surveillance  ...  inpatients_sari_icu  \
# ...

# %%
suffix = "All types of"
filtered_columns = df.filter(like=suffix)

# %%
df.filter(like=suffix).iloc[2519]
# Out:
# A H1N12009 - All types of surveillance                    3.00000
# A H1 - All types of surveillance                              NaN
# A H3 - All types of surveillance                         46.00000
# A H5 - All types of surveillance                              NaN
# A H7N9 - All types of surveillance                            NaN
# A (unknown subtype) - All types of surveillance               NaN
# Influenza A - All types of surveillance                  49.00000
# B Yamagata - All types of surveillance                        NaN
# B Victoria - All types of surveillance                   55.00000
# B (unknown lineage) - All types of surveillance               NaN
# Influenza B - All types of surveillance                  55.00000
# All strains - All types of surveillance                 104.00000
# All types of surveillance                              1193.00000
# Share of positive tests - All types of surveillance       9.10086
# Name: 2519, dtype: float64

# %%
df=df[['Country','Month','All strains - All types of surveillance']]

# %%
df[df['Country'].isin(['India','Bangladesh','Pakistan','Nepal','Bhutan','Sri Lanka','Afghanistan','Maldives'])]['Country'].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives',
#        'Nepal', 'Pakistan', 'Sri Lanka'], dtype=object)

# %%
saarc = df[df['Country'].isin(['India','Bangladesh','Pakistan','Nepal','Bhutan','Sri Lanka','Afghanistan','Maldives'])]

# %%
saarc
# Out:
#            Country       Month  All strains - All types of surveillance
# 0      Afghanistan  2009-09-01                                      NaN
# 1      Afghanistan  2009-10-01                                    163.0
# 2      Afghanistan  2009-11-01                                     93.0
# 3      Afghanistan  2009-12-01                                     27.0
# 4      Afghanistan  2010-01-01                                      0.0
# ...            ...         ...                                      ...
# 25583    Sri Lanka  2023-02-01                                     31.0
# 25584    Sri Lanka  2023-03-01                                     24.0
# 25585    Sri Lanka  2023-04-01                                     56.0
# 25586    Sri Lanka  2023-05-01                                    110.0
# 25587    Sri Lanka  2023-06-01                                     42.0
#
# [1247 rows x 3 columns]

# %%
saarc[saarc['Country']=='Bangladesh'].plot()
saarc[saarc['Country']=='India'].plot()
# Out:
# <Axes: >

# %%
sns.lineplot(saarc[saarc['Country']=='Bangladesh'])
# Out:
# <Axes: >

# %%
saarc['Month'].sort_values()
# Out:
# 11986    2009-01-01
# 25414    2009-01-01
# 20163    2009-01-01
# 25415    2009-02-01
# 11987    2009-02-01
#             ...
# 12159    2023-06-01
# 15698    2023-06-01
# 20336    2023-06-01
# 165      2023-06-01
# 25587    2023-06-01
# Name: Month, Length: 1247, dtype: object

# %%
ban = saarc[saarc['Country']=='Bangladesh']

# %%
saarc['Month']=pd.to_datetime(saarc['Month'])
# Out:
# <ipython-input-17-c6f4a7dfa8e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   saarc['Month']=pd.to_datetime(saarc['Month'])

# %%
saarc.rename(columns={'All strains - All types of surveillance':'ConfirmedCases'},inplace=True)
# Out:
# <ipython-input-18-923b3a2d112e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   saarc.rename(columns={'All strains - All types of surveillance':'ConfirmedCases'},inplace=True)

# %%
saarc
# Out:
#            Country      Month  ConfirmedCases
# 0      Afghanistan 2009-09-01             NaN
# 1      Afghanistan 2009-10-01           163.0
# 2      Afghanistan 2009-11-01            93.0
# 3      Afghanistan 2009-12-01            27.0
# 4      Afghanistan 2010-01-01             0.0
# ...            ...        ...             ...
# 25583    Sri Lanka 2023-02-01            31.0
# 25584    Sri Lanka 2023-03-01            24.0
# 25585    Sri Lanka 2023-04-01            56.0
# 25586    Sri Lanka 2023-05-01           110.0
# 25587    Sri Lanka 2023-06-01            42.0
#
# [1247 rows x 3 columns]

# %%
ban
# Out:
#          Country       Month  All strains - All types of surveillance
# 2358  Bangladesh  2010-01-01                                     13.0
# 2359  Bangladesh  2010-02-01                                     16.0
# 2360  Bangladesh  2010-03-01                                     39.0
# 2361  Bangladesh  2010-04-01                                     53.0
# 2362  Bangladesh  2010-05-01                                     77.0
# ...          ...         ...                                      ...
# 2515  Bangladesh  2023-02-01                                      9.0
# 2516  Bangladesh  2023-03-01                                     14.0
# 2517  Bangladesh  2023-04-01                                     25.0
# 2518  Bangladesh  2023-05-01                                     45.0
# 2519  Bangladesh  2023-06-01                                    104.0
#
# [162 rows x 3 columns]

# %%
ban.to_csv('Ban1.csv')

# %%
ind = saarc[saarc['Country']=='India']
ind
# Out:
#       Country      Month  ConfirmedCases
# 11986   India 2009-01-01             NaN
# 11987   India 2009-02-01             1.0
# 11988   India 2009-03-01             1.0
# 11989   India 2009-04-01             0.0
# 11990   India 2009-05-01             0.0
# ...       ...        ...             ...
# 12155   India 2023-02-01           325.0
# 12156   India 2023-03-01           406.0
# 12157   India 2023-04-01           181.0
# 12158   India 2023-05-01           162.0
# 12159   India 2023-06-01           183.0
#
# [174 rows x 3 columns]

# %%
ind.to_csv('Ind1.csv')

# %%
nep = saarc[saarc['Country']=='Nepal']
nep['ConfirmedCases'].plot()
# Out:
# <Axes: >

# %%
nep.to_csv('Nep1.csv')

# %%
nep
# Out:
#       Country      Month  ConfirmedCases
# 17939   Nepal 2011-06-01             4.0
# 17940   Nepal 2011-07-01             0.0
# 17941   Nepal 2011-08-01             0.0
# 17942   Nepal 2011-09-01             0.0
# 17943   Nepal 2011-10-01            16.0
# ...       ...        ...             ...
# 18079   Nepal 2023-02-01           166.0
# 18080   Nepal 2023-03-01           121.0
# 18081   Nepal 2023-04-01            61.0
# 18082   Nepal 2023-05-01            29.0
# 18083   Nepal 2023-06-01            18.0
#
# [145 rows x 3 columns]

# %%
afg = saarc[saarc['Country']=='Afghanistan']
afg
# Out:
#          Country      Month  ConfirmedCases
# 0    Afghanistan 2009-09-01             NaN
# 1    Afghanistan 2009-10-01           163.0
# 2    Afghanistan 2009-11-01            93.0
# 3    Afghanistan 2009-12-01            27.0
# 4    Afghanistan 2010-01-01             0.0
# ..           ...        ...             ...
# 161  Afghanistan 2023-02-01            28.0
# 162  Afghanistan 2023-03-01            14.0
# 163  Afghanistan 2023-04-01             1.0
# 164  Afghanistan 2023-05-01             1.0
# 165  Afghanistan 2023-06-01             NaN
#
# [166 rows x 3 columns]

# %%
afg.to_csv('Afg1.csv')

# %%
pak = saarc[saarc['Country']=='Pakistan']

# %%
pak.to_csv('Pak1.csv')

# %%
bhu = saarc[saarc['Country']=='Bhutan']
bhu
# Out:
#      Country      Month  ConfirmedCases
# 3330  Bhutan 2011-01-01             NaN
# 3331  Bhutan 2011-02-01             NaN
# 3332  Bhutan 2011-03-01             NaN
# 3333  Bhutan 2011-04-01            23.0
# 3334  Bhutan 2011-05-01            14.0
# ...      ...        ...             ...
# 3475  Bhutan 2023-02-01            38.0
# 3476  Bhutan 2023-03-01            39.0
# 3477  Bhutan 2023-04-01           101.0
# 3478  Bhutan 2023-05-01            61.0
# 3479  Bhutan 2023-06-01            47.0
#
# [150 rows x 3 columns]

# %%
bhu.to_csv('Bhu1.csv')

# %%
mal = saarc[saarc['Country']=='Maldives']
mal
# Out:
#         Country      Month  ConfirmedCases
# 15597  Maldives 2015-01-01             NaN
# 15598  Maldives 2015-02-01             1.0
# 15599  Maldives 2015-03-01             0.0
# 15600  Maldives 2015-04-01             0.0
# 15601  Maldives 2015-05-01             0.0
# ...         ...        ...             ...
# 15694  Maldives 2023-02-01             6.0
# 15695  Maldives 2023-03-01            33.0
# 15696  Maldives 2023-04-01            11.0
# 15697  Maldives 2023-05-01            49.0
# 15698  Maldives 2023-06-01            51.0
#
# [102 rows x 3 columns]

# %%
mal.to_csv('Mal1.csv')

# %%
sri = saarc[saarc['Country']=='Sri Lanka']
sri.to_csv('Sri1.csv')
